# %% [markdown]
# # Plot Ultrastrong

# %%
import numpy as np
import numpy.random as rn
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
from qutip import *

from scipy.linalg import expm

matplotlib.rcParams['text.usetex'] = True
matplotlib.rcParams['text.latex.preamble'] = r'\usepackage{bm}'
matplotlib.rcParams['font.size'] = 9
matplotlib.rcParams['legend.fontsize'] = 8

# %%
data_10 = np.array(pd.read_csv(r'../other_data/sz_alpha_2D_sx_sz_10.csv'))
data_20 = np.array(pd.read_csv(r'../other_data/sz_alpha_2D_sx_sz_20.csv'))
data_30 = np.array(pd.read_csv(r'../other_data/sz_alpha_2D_sx_sz_30.csv'))
data_40 = np.array(pd.read_csv(r'../other_data/sz_alpha_2D_sx_sz_40.csv'))

# %%
fig, ax = plt.subplots(1, 1, figsize=(3.75, 3))  #size in inches

bcmap = plt.get_cmap('Blues')
ocmap = plt.get_cmap('YlGn')
gcmap = plt.get_cmap('Greys')

ax.set_xlabel("$\\alpha$")
ax.set_ylabel("$s_z$")

ax.set_ylim(0.5, 1.05)

# ax.semilogx(data_10[:,0], data_10[:,1], color=bcmap(0.4), label='$ n = 10$')
# ax.semilogx(data_20[:,0], data_20[:,1], color=bcmap(0.6), label='$ n = 20$')
# ax.semilogx(data_30[:,0], data_30[:,1], color=bcmap(0.8), label='$ n = 30$')
# ax.semilogx(data_40[:,0], data_40[:,1], color=bcmap(1.0), label='$ n = 40$')

ax.semilogx(data_10[:,0], data_10[:,2], color=bcmap(0.4), linestyle='--', label='$ n = 10$ (transformed)')
ax.semilogx(data_20[:,0], data_20[:,2], color=bcmap(0.6), linestyle='--', label='$ n = 20$ (transformed)')
ax.semilogx(data_30[:,0], data_30[:,2], color=bcmap(0.8), linestyle='--', label='$ n = 30$ (transformed)')
ax.semilogx(data_40[:,0], data_40[:,2], color=bcmap(1.0), linestyle='--', label='$ n = 40$ (transformed)')

ax.legend(ncol=1, loc='lower left', frameon=False, handlelength=1.8)

fig.tight_layout(w_pad = 1.4)

plt.savefig('C://Users//crh222//Dropbox//charlie//multi_bath//ultrastrong//sz_alpha_n_2D_sx_sz_transformed.pdf', dpi=300) # Export for Windows

# %%
fig, ax = plt.subplots(1, 1, figsize=(3.75, 3))  #size in inches

bcmap = plt.get_cmap('Blues')
ocmap = plt.get_cmap('YlGn')
gcmap = plt.get_cmap('Greys')

ax.set_xlabel("$\\alpha$")
ax.set_ylabel("$s_z$")

ax.set_ylim(0.4, 1.05)

ax.semilogx(data_10[:,0], data_10[:,1], color=bcmap(0.4), label='$n = 10$')
ax.semilogx(data_20[:,0], data_20[:,1], color=bcmap(0.6), label='$n = 20$')
ax.semilogx(data_30[:,0], data_30[:,1], color=bcmap(0.8), label='$n = 30$')
ax.semilogx(data_40[:,0], data_40[:,1], color=bcmap(1.0), label='$n = 40$')

# ax.semilogx(data_10[:,0], data_10[:,2], color=bcmap(0.4), linestyle='--', label='$n = 10$ (transformed)')
# ax.semilogx(data_20[:,0], data_20[:,2], color=bcmap(0.6), linestyle='--', label='$n = 20$ (transformed)')
# ax.semilogx(data_30[:,0], data_30[:,2], color=bcmap(0.8), linestyle='--', label='$n = 30$ (transformed)')
# ax.semilogx(data_40[:,0], data_40[:,2], color=bcmap(1.0), linestyle='--', label='$n = 40$ (transformed)')

ax.axhline(1/np.sqrt(2), color='gray', linestyle='--', label='$1/\sqrt{2}$')
 
ax.legend(ncol=1, loc='lower left', frameon=False, handlelength=1.8)

fig.tight_layout(w_pad = 1.4)

plt.savefig('C://Users//crh222//Dropbox//charlie//multi_bath//ultrastrong//sz_alpha_n_2D_sx_sz_untransformed.pdf', dpi=300) # Export for Windows

# %%
fig, ax = plt.subplots(1, 1, figsize=(3.75, 3))  #size in inches

bcmap = plt.get_cmap('Blues')
ocmap = plt.get_cmap('YlGn')
gcmap = plt.get_cmap('Greys')

ax.set_xlabel("$\\alpha$")
ax.set_ylabel("$s_z$")

ax.set_ylim(0.4, 1.05)

# ax.semilogx(data_10[:,0], data_10[:,1], color=bcmap(0.4), label='$n = 10$')
# ax.semilogx(data_20[:,0], data_20[:,1], color=bcmap(0.6), label='$n = 20$')
# ax.semilogx(data_30[:,0], data_30[:,1], color=bcmap(0.8), label='$n = 30$')
ax.semilogx(data_40[:,0], data_40[:,1], color=bcmap(1.0), label='$n = 40$')

# ax.semilogx(data_10[:,0], data_10[:,2], color=bcmap(0.4), linestyle='--', label='$n = 10$ (transformed)')
# ax.semilogx(data_20[:,0], data_20[:,2], color=bcmap(0.6), linestyle='--', label='$n = 20$ (transformed)')
# ax.semilogx(data_30[:,0], data_30[:,2], color=bcmap(0.8), linestyle='--', label='$n = 30$ (transformed)')
ax.semilogx(data_40[:,0], data_40[:,2], color=bcmap(1.0), linestyle='--', label='$n = 40$ (transformed)')

# ax.axhline(1/np.sqrt(2), color='gray', linestyle='--', label='$1/\sqrt{2}$')
 
ax.legend(ncol=1, loc='lower left', frameon=False, handlelength=1.8)

fig.tight_layout(w_pad = 1.4)

plt.savefig('C://Users//crh222//Dropbox//charlie//multi_bath//ultrastrong//sz_alpha_40_2D_sx_sz_ut_t.pdf', dpi=300) # Export for Windows

# %%
fig, ax = plt.subplots(1, 1, figsize=(3.75, 3))  #size in inches

bcmap = plt.get_cmap('Blues')
ocmap = plt.get_cmap('YlGn')
gcmap = plt.get_cmap('Greys')

ax.set_xlabel("$\\alpha$")
ax.set_ylabel("$s_z$")

ax.semilogx(data_40[:,0], data_40[:,2], color=bcmap(0.6), label='$n = 40$')
ax.semilogx(data_40[:,0], data_40[:,4]/40, color='r', label='$\\overline{\langle n_1 \\rangle + \\langle n_2 \\rangle}$')
ax.axhline(0.5, linestyle='--', color='gray', zorder=0)
ax.axvline(1320, linestyle='--', color='gray', zorder=0)

ax.legend(ncol=1, loc='lower right', frameon=False, handlelength=1.8, markerfirst=False)

fig.tight_layout(w_pad = 1.4)

plt.savefig('C://Users//crh222//Dropbox//charlie//multi_bath//ultrastrong//sz_alpha_40_2D_sx_sz.pdf', dpi=300) # Export for Windows

# %%
data_pos_20_200 = np.array(pd.read_csv(r'../other_data/position_dist_20_200.csv'))
data_pos_20_400 = np.array(pd.read_csv(r'../other_data/position_dist_20_400.csv'))
data_pos_20_600 = np.array(pd.read_csv(r'../other_data/position_dist_20_600.csv'))
data_pos_20_800 = np.array(pd.read_csv(r'../other_data/position_dist_20_800.csv'))
data_pos_20_1000 = np.array(pd.read_csv(r'../other_data/position_dist_20_1000.csv'))

data_pos_30_200 = np.array(pd.read_csv(r'../other_data/position_dist_30_200.csv'))
data_pos_30_400 = np.array(pd.read_csv(r'../other_data/position_dist_30_400.csv'))
data_pos_30_600 = np.array(pd.read_csv(r'../other_data/position_dist_30_600.csv'))
data_pos_30_800 = np.array(pd.read_csv(r'../other_data/position_dist_30_800.csv'))
data_pos_30_1000 = np.array(pd.read_csv(r'../other_data/position_dist_30_1000.csv'))

# %%
fig, ax = plt.subplots(1, 2, figsize=(6.75, 3))  #size in inches

bcmap = plt.get_cmap('Blues')
ocmap = plt.get_cmap('YlGn')
gcmap = plt.get_cmap('Greys')

ax[0].set_xlabel("$x$")
ax[0].set_ylabel("$P(x)$")
ax[1].set_xlabel("$x$")

ax[0].set_xlim(-8, 8)
ax[1].set_xlim(-8, 8)

ax[0].set_ylim(0, 10)
ax[1].set_ylim(0, 10)

ax[0].plot(data_pos_20_200[:,0], data_pos_20_200[:,1], label="$\\alpha = 200$")
ax[0].plot(data_pos_20_400[:,0], data_pos_20_400[:,1], label="$\\alpha = 400$")
ax[0].plot(data_pos_20_600[:,0], data_pos_20_600[:,1], label="$\\alpha = 600$")
ax[0].plot(data_pos_20_800[:,0], data_pos_20_800[:,1], label="$\\alpha = 800$")
ax[0].plot(data_pos_20_1000[:,0], data_pos_20_1000[:,1], label="$\\alpha = 1000$")

ax[0].axvline(-5.39, color='grey')
ax[0].axvline(5.39, color='grey')
ax[0].axvspan(5.39, 8, color='grey', alpha=0.4)
ax[0].axvspan(-8, -5.39, color='grey', alpha=0.4)

ax[0].legend(ncol=1, loc='upper left', handlelength=1.8)

ax[1].plot(data_pos_30_200[:,0], data_pos_30_200[:,1], label="$\\alpha = 200$")
ax[1].plot(data_pos_30_400[:,0], data_pos_30_400[:,1], label="$\\alpha = 400$")
ax[1].plot(data_pos_30_600[:,0], data_pos_30_600[:,1], label="$\\alpha = 600$")
ax[1].plot(data_pos_20_800[:,0], data_pos_30_800[:,1], label="$\\alpha = 800$")
ax[1].plot(data_pos_30_1000[:,0], data_pos_30_1000[:,1], label="$\\alpha = 1000$")

ax[1].axvline(-6.86, color='grey')
ax[1].axvline(6.86, color='grey')
ax[1].axvspan(6.86, 8, color='grey', alpha=0.4)
ax[1].axvspan(-8, -6.86, color='grey', alpha=0.4)

ax[0].text(2.5, 9.25, '$\\bm{n = 20}$')
ax[1].text(3.9, 9.25, '$\\bm{n = 30}$')

fig.tight_layout(w_pad = 1.4)

plt.savefig('C://Users//crh222//Dropbox//charlie//multi_bath//ultrastrong//position_distribution.pdf', dpi=300) # Export for Windows
